# %% [markdown]
# ## Optimizing -- Attempt 1

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
application_df = application_df.drop(columns=["EIN","NAME","SPECIAL_CONSIDERATIONS"])
application_df.head()
# Out:
#   APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0              T10       Independent          C1000    ProductDev
# 1               T3       Independent          C2000  Preservation
# 2               T5  CompanySponsored          C3000    ProductDev
# 3               T3  CompanySponsored          C2000  Preservation
# 4               T3       Independent          C1000     Heathcare
#
#    ORGANIZATION  STATUS     INCOME_AMT  ASK_AMT  IS_SUCCESSFUL
# 0   Association       1              0     5000              1
# 1  Co-operative       1         1-9999   108590              1
# 2   Association       1              0     5000              0
# 3         Trust       1    10000-24999     6692              1
# 4         Trust       1  100000-499999   142590              1

# %%
# Determine the number of unique values in each column.
application_df.nunique()
# Out:
# APPLICATION_TYPE      17
# AFFILIATION            6
# CLASSIFICATION        71
# USE_CASE               5
# ORGANIZATION           4
# STATUS                 2
# INCOME_AMT             9
# ASK_AMT             8747
# IS_SUCCESSFUL          2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
application_df["APPLICATION_TYPE"].value_counts()
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
counts = application_df["APPLICATION_TYPE"].value_counts()
application_types_to_replace = list(counts[counts < 200].index)

# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: CLASSIFICATION, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
counts = application_df["CLASSIFICATION"].value_counts()

print(counts[counts>1])
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C2400        6
# C1720        6
# C4100        6
# C1257        5
# C1600        5
# C1260        3
# C2710        3
# C0           3
# C3200        2
# C1234        2
# C1246        2
# C1267        2
# C1256        2
# Name: CLASSIFICATION, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
classifications_to_replace = list(counts[counts < 2].index)

# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")

# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# Other       26
# C8000       20
# C7120       18
# C1500       16
# C6000       15
# C1800       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1237        9
# C1235        9
# C7210        7
# C1720        6
# C2400        6
# C4100        6
# C1257        5
# C1600        5
# C1260        3
# C2710        3
# C0           3
# C1267        2
# C1256        2
# C1234        2
# C1246        2
# C3200        2
# Name: CLASSIFICATION, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
app_dummies_df = pd.get_dummies(application_df)

# %%
# Split our preprocessed data into our features and target arrays
y = app_dummies_df['IS_SUCCESSFUL']
X = app_dummies_df.drop(columns='IS_SUCCESSFUL')

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
number_input_features = len(X_train_scaled[0])
hidden_nodes_layer1 =  10
hidden_nodes_layer2 = 5

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer1, activation='relu',input_dim=number_input_features))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation='relu'))

# Third hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation='relu'))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 10)                820
#
#  dense_1 (Dense)             (None, 5)                 55
#
#  dense_2 (Dense)             (None, 5)                 30
#
#  dense_3 (Dense)             (None, 1)                 6
#
# =================================================================
# Total params: 911 (3.56 KB)
# Trainable params: 911 (3.56 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy",optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn.fit(X_train_scaled,y_train,epochs=20)
# Out:
# Epoch 1/20
# 804/804 [==============================] - 2s 1ms/step - loss: 0.6249 - accuracy: 0.6847
# Epoch 2/20
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5832 - accuracy: 0.7254
# Epoch 3/20
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5725 - accuracy: 0.7286
# Epoch 4/20
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5685 - accuracy: 0.7281
# Epoch 5/20
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5660 - accuracy: 0.7303
# Epoch 6/20
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5646 - accuracy: 0.7292
# Epoch 7/20
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5623 - accuracy: 0.7303
# Epoch 8/20
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5599 - accuracy: 0.7312
# Epoch 9/20
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5573 - accuracy: 0.7311
# Epoch 10/20
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5552 - accuracy: 0.7310
# Epoch 11/20
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5535 - accuracy: 0.7315
# Epoch 12/20
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5524 - accuracy: 0.7317
# Epoch 13/20
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5512 - accuracy: 0.7314
# Epoch 14/20
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5506 - accuracy: 0.7327
# Epoch 15/20
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5499 - accuracy: 0.7320
# Epoch 16/20
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5492 - accuracy: 0.7315
# Epoch 17/20
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5486 - accuracy: 0.7335
# Epoch 18/20
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5481 - accuracy: 0.7325
# Epoch 19/20
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5478 - accuracy: 0.7331
# Epoch 20/20
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5474 - accuracy: 0.7331

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5594 - accuracy: 0.7286 - 318ms/epoch - 1ms/step
# Loss: 0.5593633651733398, Accuracy: 0.7286297082901001

# %% [markdown]
# ## Optimize -- Attempt 2

# %%
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
application_df = application_df.drop(columns=["EIN","NAME","SPECIAL_CONSIDERATIONS"])
application_df.head()
# Out:
#   APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0              T10       Independent          C1000    ProductDev
# 1               T3       Independent          C2000  Preservation
# 2               T5  CompanySponsored          C3000    ProductDev
# 3               T3  CompanySponsored          C2000  Preservation
# 4               T3       Independent          C1000     Heathcare
#
#    ORGANIZATION  STATUS     INCOME_AMT  ASK_AMT  IS_SUCCESSFUL
# 0   Association       1              0     5000              1
# 1  Co-operative       1         1-9999   108590              1
# 2   Association       1              0     5000              0
# 3         Trust       1    10000-24999     6692              1
# 4         Trust       1  100000-499999   142590              1

# %%
# Determine the number of unique values in each column.
application_df.nunique()
# Out:
# APPLICATION_TYPE      17
# AFFILIATION            6
# CLASSIFICATION        71
# USE_CASE               5
# ORGANIZATION           4
# STATUS                 2
# INCOME_AMT             9
# ASK_AMT             8747
# IS_SUCCESSFUL          2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
application_df["APPLICATION_TYPE"].value_counts()
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
counts = application_df["APPLICATION_TYPE"].value_counts()
application_types_to_replace = list(counts[counts < 200].index)

# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: CLASSIFICATION, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
counts = application_df["CLASSIFICATION"].value_counts()

print(counts[counts>1])
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C2400        6
# C1720        6
# C4100        6
# C1257        5
# C1600        5
# C1260        3
# C2710        3
# C0           3
# C3200        2
# C1234        2
# C1246        2
# C1267        2
# C1256        2
# Name: CLASSIFICATION, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
classifications_to_replace = list(counts[counts < 10].index)

# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")

# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# Other       98
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# Name: CLASSIFICATION, dtype: int64

# %%
# Look at ASK_AMT value counts for binning
counts = application_df["ASK_AMT"].value_counts()
print(counts[counts>1])
# Out:
# 5000      25398
# 10478         3
# 15583         3
# 63981         3
# 6725          3
#           ...
# 100000        2
# 8181          2
# 24746         2
# 45793         2
# 240780        2
# Name: ASK_AMT, Length: 152, dtype: int64

# %%
# Choose a cutoff value and create a list of amounts to be replaced
# use the variable name `amounts_to_replace`
amounts_to_replace = list(counts[counts < 2].index)

# Replace in dataframe
for amt in amounts_to_replace:
    application_df['ASK_AMT'] = application_df['ASK_AMT'].replace(amt,"Other")

# Check to make sure binning was successful
application_df['ASK_AMT'].value_counts()
# Out:
# 5000     25398
# Other     8595
# 63981        3
# 15583        3
# 6725         3
#          ...
# 40429        2
# 57588        2
# 20537        2
# 34875        2
# 5731         2
# Name: ASK_AMT, Length: 153, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
app_dummies_df = pd.get_dummies(application_df)

# %%
# Split our preprocessed data into our features and target arrays
y = app_dummies_df['IS_SUCCESSFUL']
X = app_dummies_df.drop(columns='IS_SUCCESSFUL')

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
number_input_features = len(X_train_scaled[0])
hidden_nodes_layer1 = 10
hidden_nodes_layer2 = 10

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer1, activation='relu',input_dim=number_input_features))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation='relu'))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_30 (Dense)            (None, 10)                2260
#
#  dense_31 (Dense)            (None, 10)                110
#
#  dense_32 (Dense)            (None, 1)                 11
#
# =================================================================
# Total params: 2381 (9.30 KB)
# Trainable params: 2381 (9.30 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy",optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn.fit(X_train_scaled,y_train,epochs=20)
# Out:
# Epoch 1/20
# 804/804 [==============================] - 5s 3ms/step - loss: 0.5950 - accuracy: 0.7047
# Epoch 2/20
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5584 - accuracy: 0.7255
# Epoch 3/20
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5510 - accuracy: 0.7282
# Epoch 4/20
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5484 - accuracy: 0.7298
# Epoch 5/20
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5465 - accuracy: 0.7314
# Epoch 6/20
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5451 - accuracy: 0.7318
# Epoch 7/20
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5440 - accuracy: 0.7333
# Epoch 8/20
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5437 - accuracy: 0.7322
# Epoch 9/20
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5427 - accuracy: 0.7322
# Epoch 10/20
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5420 - accuracy: 0.7323
# Epoch 11/20
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5415 - accuracy: 0.7334
# Epoch 12/20
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5408 - accuracy: 0.7345
# Epoch 13/20
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5406 - accuracy: 0.7338
# Epoch 14/20
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5403 - accuracy: 0.7340
# Epoch 15/20
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5395 - accuracy: 0.7343
# Epoch 16/20
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5392 - accuracy: 0.7347
# Epoch 17/20
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5392 - accuracy: 0.7341
# Epoch 18/20
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5388 - accuracy: 0.7339
# Epoch 19/20
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5387 - accuracy: 0.7361
# Epoch 20/20
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5382 - accuracy: 0.7357

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 1s - loss: 0.5872 - accuracy: 0.7265 - 946ms/epoch - 4ms/step
# Loss: 0.5871917009353638, Accuracy: 0.7265306115150452

# %% [markdown]
# ## Optimize -- Attempt 3

# %%
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Drop the non-beneficial ID columns, 'EIN', 'NAME' and others
application_df = application_df.drop(columns=["EIN","NAME","SPECIAL_CONSIDERATIONS","USE_CASE"])
application_df.head()
# Out:
#   APPLICATION_TYPE       AFFILIATION CLASSIFICATION  ORGANIZATION  STATUS  \
# 0              T10       Independent          C1000   Association       1
# 1               T3       Independent          C2000  Co-operative       1
# 2               T5  CompanySponsored          C3000   Association       1
# 3               T3  CompanySponsored          C2000         Trust       1
# 4               T3       Independent          C1000         Trust       1
#
#       INCOME_AMT  ASK_AMT  IS_SUCCESSFUL
# 0              0     5000              1
# 1         1-9999   108590              1
# 2              0     5000              0
# 3    10000-24999     6692              1
# 4  100000-499999   142590              1

# %%
# Determine the number of unique values in each column.
application_df.nunique()
# Out:
# APPLICATION_TYPE      17
# AFFILIATION            6
# CLASSIFICATION        71
# ORGANIZATION           4
# STATUS                 2
# INCOME_AMT             9
# ASK_AMT             8747
# IS_SUCCESSFUL          2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
application_df["APPLICATION_TYPE"].value_counts()
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
counts = application_df["APPLICATION_TYPE"].value_counts()
application_types_to_replace = list(counts[counts < 200].index)

# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: CLASSIFICATION, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
counts = application_df["CLASSIFICATION"].value_counts()

print(counts[counts>1])
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C2400        6
# C1720        6
# C4100        6
# C1257        5
# C1600        5
# C1260        3
# C2710        3
# C0           3
# C3200        2
# C1234        2
# C1246        2
# C1267        2
# C1256        2
# Name: CLASSIFICATION, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
classifications_to_replace = list(counts[counts < 500].index)

# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")

# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# Other     1484
# C7000      777
# Name: CLASSIFICATION, dtype: int64

# %%
# Look at ASK_AMT value counts for binning
counts = application_df["ASK_AMT"].value_counts()
print(counts[counts>1])
# Out:
# 5000      25398
# 10478         3
# 15583         3
# 63981         3
# 6725          3
#           ...
# 100000        2
# 8181          2
# 24746         2
# 45793         2
# 240780        2
# Name: ASK_AMT, Length: 152, dtype: int64

# %%
# Choose a cutoff value and create a list of amounts to be replaced
# use the variable name `amounts_to_replace`
amounts_to_replace = list(counts[counts < 2].index)

# Replace in dataframe
for amt in amounts_to_replace:
    application_df['ASK_AMT'] = application_df['ASK_AMT'].replace(amt,"Other")

# Check to make sure binning was successful
application_df['ASK_AMT'].value_counts()
# Out:
# 5000     25398
# Other     8595
# 63981        3
# 15583        3
# 6725         3
#          ...
# 40429        2
# 57588        2
# 20537        2
# 34875        2
# 5731         2
# Name: ASK_AMT, Length: 153, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
app_dummies_df = pd.get_dummies(application_df)

# %%
# Split our preprocessed data into our features and target arrays
y = app_dummies_df['IS_SUCCESSFUL']
X = app_dummies_df.drop(columns='IS_SUCCESSFUL').values

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
number_input_features = len(X_train_scaled[0])
hidden_nodes_layer1 = 10
hidden_nodes_layer2 = 16

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer1, activation='relu',input_dim=number_input_features))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation='relu'))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_4 (Dense)             (None, 10)                820
#
#  dense_5 (Dense)             (None, 16)                176
#
#  dense_6 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 1013 (3.96 KB)
# Trainable params: 1013 (3.96 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy",optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn.fit(X_train_scaled,y_train,epochs=20)
# Out:
# Epoch 1/20
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5965 - accuracy: 0.7078
# Epoch 2/20
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5595 - accuracy: 0.7279
# Epoch 3/20
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5544 - accuracy: 0.7292
# Epoch 4/20
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5520 - accuracy: 0.7310
# Epoch 5/20
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5505 - accuracy: 0.7313
# Epoch 6/20
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5493 - accuracy: 0.7303
# Epoch 7/20
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5483 - accuracy: 0.7311
# Epoch 8/20
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5476 - accuracy: 0.7318
# Epoch 9/20
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5467 - accuracy: 0.7323
# Epoch 10/20
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5462 - accuracy: 0.7320
# Epoch 11/20
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5455 - accuracy: 0.7333
# Epoch 12/20
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5453 - accuracy: 0.7324
# Epoch 13/20
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5448 - accuracy: 0.7334
# Epoch 14/20
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5443 - accuracy: 0.7328
# Epoch 15/20
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5442 - accuracy: 0.7331
# Epoch 16/20
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5439 - accuracy: 0.7325
# Epoch 17/20
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5436 - accuracy: 0.7340
# Epoch 18/20
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5436 - accuracy: 0.7336
# Epoch 19/20
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5434 - accuracy: 0.7338
# Epoch 20/20
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5429 - accuracy: 0.7342

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5862 - accuracy: 0.7296 - 441ms/epoch - 2ms/step
# Loss: 0.5861994624137878, Accuracy: 0.7295626997947693

# %%
# Export our model to HDF5 file
nn.save("AlphabetSoupCharity_Optimization.h5")
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
